# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1><p style="text-align: center;">Pandas Lesson, Session - 7</p><h1>

# %% [markdown]
# # Handling with Missing Values

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
id_no = ["P001","P002","P003","P004","P005","P006","P007","P008","P009","P010","P011"]
gender=["M","F","M","F","M","F","M","F","M","F","M"]
status = ["FT","PT","-","FT","PT","PT","FT","-","PT","FT",np.nan]
dept = ["DS","FS","AWS","AWS","DS",np.nan,"FS","FS",np.nan,"DS","AWS"]
V1 = np.array([2,3,5,np.nan,7,1,np.nan,10,14,"-",6])
V2 = np.array([8,np.nan,5,8,11,np.nan,np.nan,2,3,7,9])
salary = np.array([np.nan,54,59,120,58,75,np.nan,136,60,125,np.nan])
df = pd.DataFrame({
                   "id" : id_no,
                   "gender": gender,
                   "status": status,
                   "dept": dept,
                   "var1" : V1,
                   "var2" : V2,
                   "salary" : salary
                  })
df
# Out:
#       id gender status dept var1  var2  salary
# 0   P001      M     FT   DS    2   8.0     NaN
# 1   P002      F     PT   FS    3   NaN    54.0
# 2   P003      M      -  AWS    5   5.0    59.0
# 3   P004      F     FT  AWS  nan   8.0   120.0
# 4   P005      M     PT   DS    7  11.0    58.0
# 5   P006      F     PT  NaN    1   NaN    75.0
# 6   P007      M     FT   FS  nan   NaN     NaN
# 7   P008      F      -   FS   10   2.0   136.0
# 8   P009      M     PT  NaN   14   3.0    60.0
# 9   P010      F     FT   DS    -   7.0   125.0
# 10  P011      M    NaN  AWS    6   9.0     NaN

# %% [markdown]
# ## Type of NaN Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  10 non-null     object
#  3   dept    9 non-null      object
#  4   var1    11 non-null     object
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      float64
# dtypes: float64(2), object(5)
# memory usage: 744.0+ bytes

# %%
type(np.nan)
# Out:
# float

# %%
type(np.NaN)
# Out:
# float

# %%
type(None)
# Out:
# NoneType

# %%
df.salary
# Out:
# 0       NaN
# 1      54.0
# 2      59.0
# 3     120.0
# 4      58.0
# 5      75.0
# 6       NaN
# 7     136.0
# 8      60.0
# 9     125.0
# 10      NaN
# Name: salary, dtype: float64

# %%
type(df.salary[0])
# Out:
# numpy.float64

# %%
type(df.salary[1])
# Out:
# numpy.float64

# %%
df.status
# Out:
# 0      FT
# 1      PT
# 2       -
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7       -
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
type(df.status[2])
# Out:
# str

# %%
type(df.status[10])
# Out:
# float

# %%
df.var1
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %%
type(df.var1[3])
# Out:
# str

# %%
type(df.var1[9])
# Out:
# str

# %% [markdown]
# **What is the None keyword in Python?**
#
# https://www.educative.io/edpresso/what-is-the-none-keyword-in-python
#
# https://stackoverflow.com/questions/21095654/what-is-a-nonetype-object
#
# **Difference between None and NaN in Pandas**
#
# https://www.skytowner.com/explore/difference_between_none_and_nan_in_pandas
#
# https://kegui.medium.com/what-is-the-difference-between-nan-none-pd-nan-and-np-nan-a8ee0532e2eb
#
# **Difference between np.nan and np.NaN**
#
# https://stackoverflow.com/questions/53436339/difference-between-np-nan-and-np-nan
#
# **Difference between nan and 'nan' in Python**
#
# https://stackoverflow.com/questions/40309789/difference-between-nan-and-nan-in-python
#
# https://towardsdatascience.com/navigating-the-hell-of-nans-in-python-71b12558895b

# %% [markdown]
# ## Detecting Missing Values

# %% [markdown]
# NaN, standing for not a number, is a numeric data type used to represent any value that is undefined or unpresentable.
#
# For example, 0/0 is undefined as a real number and is, therefore, represented by NaN. The square root of a negative number is an imaginary number that cannot be represented as a real number, so, it is represented by NaN.
#
# NaN is also assigned to variables, in a computation, that do not have values and have yet to be computed.

# %%
df
# Out:
#       id gender status dept var1  var2  salary
# 0   P001      M     FT   DS    2   8.0     NaN
# 1   P002      F     PT   FS    3   NaN    54.0
# 2   P003      M      -  AWS    5   5.0    59.0
# 3   P004      F     FT  AWS  nan   8.0   120.0
# 4   P005      M     PT   DS    7  11.0    58.0
# 5   P006      F     PT  NaN    1   NaN    75.0
# 6   P007      M     FT   FS  nan   NaN     NaN
# 7   P008      F      -   FS   10   2.0   136.0
# 8   P009      M     PT  NaN   14   3.0    60.0
# 9   P010      F     FT   DS    -   7.0   125.0
# 10  P011      M    NaN  AWS    6   9.0     NaN

# %%
df.isnull() #null olanlar True
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True

# %%
df.isna() #üstteki satır ile aynı
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True

# %%
df.notnull() #null olmayanlar True
# Out:
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# 5   True    True    True  False  True  False    True
# 6   True    True    True   True  True  False   False
# 7   True    True    True   True  True   True    True
# 8   True    True    True  False  True   True    True
# 9   True    True    True   True  True   True    True
# 10  True    True   False   True  True   True   False

# %%
df.notna() #üstteki satır ile aynı
# Out:
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# 5   True    True    True  False  True  False    True
# 6   True    True    True   True  True  False   False
# 7   True    True    True   True  True   True    True
# 8   True    True    True  False  True   True    True
# 9   True    True    True   True  True   True    True
# 10  True    True   False   True  True   True   False

# %%
df.isnull().any()
# Out:
# id        False
# gender    False
# status     True
# dept       True
# var1      False
# var2       True
# salary     True
# dtype: bool

# %%
df.isnull().any(axis=1)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# dtype: bool

# %%
df.isnull().sum() #sütunlardakini sayıyor
# Out:
# id        0
# gender    0
# status    1
# dept      2
# var1      0
# var2      3
# salary    3
# dtype: int64

# %%
df.isnull().sum().sum() #tüm datayı sayıyor
# Out:
# 9

# %%
df.salary.isnull().any() #salary sütununda var mı?
# Out:
# True

# %%
df.isnull().sum(axis=1) #satırlardakini sayıyor
# Out:
# 0     1
# 1     1
# 2     0
# 3     0
# 4     0
# 5     2
# 6     2
# 7     0
# 8     1
# 9     0
# 10    2
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# id         0.000000
# gender     0.000000
# status     9.090909
# dept      18.181818
# var1       0.000000
# var2      27.272727
# salary    27.272727
# dtype: float64

# %%
df.loc[df.isnull().any(axis=1)] #null içeren satırları getir
# Out:
#       id gender status dept var1  var2  salary
# 0   P001      M     FT   DS    2   8.0     NaN
# 1   P002      F     PT   FS    3   NaN    54.0
# 5   P006      F     PT  NaN    1   NaN    75.0
# 6   P007      M     FT   FS  nan   NaN     NaN
# 8   P009      M     PT  NaN   14   3.0    60.0
# 10  P011      M    NaN  AWS    6   9.0     NaN

# %%
df.loc[~df.isnull().any(axis=1)] #null içermeyen sütunları getir
# Out:
#      id gender status dept var1  var2  salary
# 2  P003      M      -  AWS    5   5.0    59.0
# 3  P004      F     FT  AWS  nan   8.0   120.0
# 4  P005      M     PT   DS    7  11.0    58.0
# 7  P008      F      -   FS   10   2.0   136.0
# 9  P010      F     FT   DS    -   7.0   125.0

# %%
df.loc[df.isnull().all(axis=1)] #hepsi null olanları getiremediği için boş, çünkü hepsi null olan yok
# Out:
# Empty DataFrame
# Columns: [id, gender, status, dept, var1, var2, salary]
# Index: []

# %%
df.loc[df.salary.isnull()] #salary sütununda null olan satırları getirdi
# Out:
#       id gender status dept var1  var2  salary
# 0   P001      M     FT   DS    2   8.0     NaN
# 6   P007      M     FT   FS  nan   NaN     NaN
# 10  P011      M    NaN  AWS    6   9.0     NaN

# %% [markdown]
# ## Converting inappropriate values to NaN values
#
# - map()
# - replace()

# %%
df
# Out:
#       id gender status dept var1  var2  salary
# 0   P001      M     FT   DS    2   8.0     NaN
# 1   P002      F     PT   FS    3   NaN    54.0
# 2   P003      M      -  AWS    5   5.0    59.0
# 3   P004      F     FT  AWS  nan   8.0   120.0
# 4   P005      M     PT   DS    7  11.0    58.0
# 5   P006      F     PT  NaN    1   NaN    75.0
# 6   P007      M     FT   FS  nan   NaN     NaN
# 7   P008      F      -   FS   10   2.0   136.0
# 8   P009      M     PT  NaN   14   3.0    60.0
# 9   P010      F     FT   DS    -   7.0   125.0
# 10  P011      M    NaN  AWS    6   9.0     NaN

# %%
df["var1"].map({"-":np.nan})
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# Name: var1, dtype: float64

# %% [markdown]
# **Notes:** When arg is a dictionary, values in Series that are not in the dictionary (as keys) are converted to NaN. However, if the dictionary is a dict subclass that defines __missing__ (i.e. provides a method for default values), then this default is used rather than NaN.
#
# https://www.w3resource.com/pandas/series/series-map.php#:~:text=The%20map()%20function%20is,a%20dict%20or%20a%20Series.&text=Mapping%20correspondence.&text=If%20'ignore'%2C%20propagate%20NaN,them%20to%20the%20mapping%20correspondence.

# %%
df["var1"].replace(to_replace="-", value=np.nan) #var1 sütunundaki - değerini NaN yaptı
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9     NaN
# 10      6
# Name: var1, dtype: object

# %%
df["var1"].replace(to_replace="-", value=np.nan).astype("float") #tipini de float yaptı
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df["var1"] = df["var1"].replace(to_replace="-", value=np.nan).astype("float") #df.var1 sütununa atayarak kalıcı yaptık

# %%
df.var1
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df["status"]
# Out:
# 0      FT
# 1      PT
# 2       -
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7       -
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
df["status"] = df["status"].replace("-", np.nan)
df["status"] #- leri Nan yaptı, to_replace yazmasak da olur(find,replace gibi)
# Out:
# 0      FT
# 1      PT
# 2     NaN
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7     NaN
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.isnull().sum()
# Out:
# id        0
# gender    0
# status    3
# dept      2
# var1      3
# var2      3
# salary    3
# dtype: int64

# %% [markdown]
# ## Missing value handling methods
#
#  1. <b>Deleting Rows</b> ----->if it has more than 70-75% of missing values. This percentage can change according to the data. So each situation should be evaluated case by case.
#
#  2. <b>Replacing With Mean/Median/Mode (Imputation)</b>--->can be applied on a feature which has numeric data
#
#  3. <b> Assigning An Unique Category</b>--->If a categorical feature has definite number of classes, we can assign another class
#
#  4. <b>Predicting The Missing Values</b>---> we can predict the nulls with the help of a machine learning algorithm like linear regression
#
#  5. <b>Using Algorithms Which Support Missing Values</b>--->KNN is a machine learning algorithm which works on the principle of distance measure.  This algorithm can be used when there are nulls present in the dataset.  KNN considers the missing values by taking the majority of the K nearest values

# %% [markdown]
#  ### Dropping
#
#  - dropna()
#  - drop()

# %%
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.dropna(axis=0, how="any", thresh=None, inplace=False)
# Out:
#      id gender status dept  var1  var2  salary
# 4  P005      M     PT   DS   7.0  11.0    58.0

# %%
df.dropna(axis=1, how="any", thresh=None, inplace=False)
# Out:
#       id gender
# 0   P001      M
# 1   P002      F
# 2   P003      M
# 3   P004      F
# 4   P005      M
# 5   P006      F
# 6   P007      M
# 7   P008      F
# 8   P009      M
# 9   P010      F
# 10  P011      M

# %%
df.dropna(axis=1, how="all", thresh=None, inplace=False)
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %% [markdown]
# * 'any' : If any NA values are present, drop that row or column.
# * 'all' : If all values are NA, drop that row or column.
#
# https://www.journaldev.com/33492/pandas-dropna-drop-null-na-values-from-dataframe

# %%
df["delete_me"] = np.nan
df
# Out:
#       id gender status dept  var1  var2  salary  delete_me
# 0   P001      M     FT   DS   2.0   8.0     NaN        NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0        NaN
# 2   P003      M    NaN  AWS   5.0   5.0    59.0        NaN
# 3   P004      F     FT  AWS   NaN   8.0   120.0        NaN
# 4   P005      M     PT   DS   7.0  11.0    58.0        NaN
# 5   P006      F     PT  NaN   1.0   NaN    75.0        NaN
# 6   P007      M     FT   FS   NaN   NaN     NaN        NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0        NaN
# 8   P009      M     PT  NaN  14.0   3.0    60.0        NaN
# 9   P010      F     FT   DS   NaN   7.0   125.0        NaN
# 10  P011      M    NaN  AWS   6.0   9.0     NaN        NaN

# %%
df.dropna(axis=1, how="all", thresh=None, inplace=True) #kalıcı olarak sütundaki verilerin hepsi null ise sildi
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.dropna(axis=1, how="any", thresh=9, inplace=False) # en az 9 tane Null olmayan varsa o sütuna dokunmadı
# Out:
#       id gender dept
# 0   P001      M   DS
# 1   P002      F   FS
# 2   P003      M  AWS
# 3   P004      F  AWS
# 4   P005      M   DS
# 5   P006      F  NaN
# 6   P007      M   FS
# 7   P008      F   FS
# 8   P009      M  NaN
# 9   P010      F   DS
# 10  P011      M  AWS

# %% [markdown]
# thresh=N requires that a column has at least N **non-NaNs to survive.**
#
# https://stackoverflow.com/questions/51584906/thresh-in-dropna-for-dataframe-in-pandas-in-python/51584935

# %%
df.drop([1,3,6]) #1. 3. ve 6. index satırları siler
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.drop(["var1","var2"], axis=1) #sütun siler axis=1 yazınca
# Out:
#       id gender status dept  salary
# 0   P001      M     FT   DS     NaN
# 1   P002      F     PT   FS    54.0
# 2   P003      M    NaN  AWS    59.0
# 3   P004      F     FT  AWS   120.0
# 4   P005      M     PT   DS    58.0
# 5   P006      F     PT  NaN    75.0
# 6   P007      M     FT   FS     NaN
# 7   P008      F    NaN   FS   136.0
# 8   P009      M     PT  NaN    60.0
# 9   P010      F     FT   DS   125.0
# 10  P011      M    NaN  AWS     NaN

# %%
df.drop(index=[1,3,5]) #index veya column belirtirsek axis belirtmeye gerek yok
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.drop(columns=["var1","var2"])
# Out:
#       id gender status dept  salary
# 0   P001      M     FT   DS     NaN
# 1   P002      F     PT   FS    54.0
# 2   P003      M    NaN  AWS    59.0
# 3   P004      F     FT  AWS   120.0
# 4   P005      M     PT   DS    58.0
# 5   P006      F     PT  NaN    75.0
# 6   P007      M     FT   FS     NaN
# 7   P008      F    NaN   FS   136.0
# 8   P009      M     PT  NaN    60.0
# 9   P010      F     FT   DS   125.0
# 10  P011      M    NaN  AWS     NaN

# %% [markdown]
#  ### Filling Missing Values (Imputation)
#  - fillna()
#  - where()
#  - interpolate()

# %%
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %% [markdown]
#  #### a.Filling with a specific value

# %%
df.fillna(0) #bütün nullları sıfır yaptı
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     0.0
# 1   P002      F     PT   FS   3.0   0.0    54.0
# 2   P003      M      0  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   0.0   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT    0   1.0   0.0    75.0
# 6   P007      M     FT   FS   0.0   0.0     0.0
# 7   P008      F      0   FS  10.0   2.0   136.0
# 8   P009      M     PT    0  14.0   3.0    60.0
# 9   P010      F     FT   DS   0.0   7.0   125.0
# 10  P011      M      0  AWS   6.0   9.0     0.0

# %%
df.var1
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df.var1.fillna(0) #sadece var1 sütunundaki nulllar sıfır oldu
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      0.0
# 4      7.0
# 5      1.0
# 6      0.0
# 7     10.0
# 8     14.0
# 9      0.0
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
#  #### b.Filling with any Proper Value

# %%
df.var1.mean()
# Out:
# 6.0

# %%
df.var1
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df.var1.fillna(df["var1"].mean())
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      6.0
# 4      7.0
# 5      1.0
# 6      6.0
# 7     10.0
# 8     14.0
# 9      6.0
# 10     6.0
# Name: var1, dtype: float64

# %%
df.var1.fillna(df["var1"].median())
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      5.5
# 4      7.0
# 5      1.0
# 6      5.5
# 7     10.0
# 8     14.0
# 9      5.5
# 10     6.0
# Name: var1, dtype: float64

# %%
df.mean()
# Out:
# C:\Users\Ahmet\AppData\Local\Temp/ipykernel_2120/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# var1       6.000
# var2       6.625
# salary    85.875
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
# C:\Users\Ahmet\AppData\Local\Temp/ipykernel_2120/634187881.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#       id gender status dept  var1    var2   salary
# 0   P001      M     FT   DS   2.0   8.000   85.875
# 1   P002      F     PT   FS   3.0   6.625   54.000
# 2   P003      M    NaN  AWS   5.0   5.000   59.000
# 3   P004      F     FT  AWS   6.0   8.000  120.000
# 4   P005      M     PT   DS   7.0  11.000   58.000
# 5   P006      F     PT  NaN   1.0   6.625   75.000
# 6   P007      M     FT   FS   6.0   6.625   85.875
# 7   P008      F    NaN   FS  10.0   2.000  136.000
# 8   P009      M     PT  NaN  14.0   3.000   60.000
# 9   P010      F     FT   DS   6.0   7.000  125.000
# 10  P011      M    NaN  AWS   6.0   9.000   85.875

# %%
df.fillna({"dept":"other", "var1":df.var1.mean(), "var2":df.var2.median()})
# Out:
#       id gender status   dept  var1  var2  salary
# 0   P001      M     FT     DS   2.0   8.0     NaN
# 1   P002      F     PT     FS   3.0   7.5    54.0
# 2   P003      M    NaN    AWS   5.0   5.0    59.0
# 3   P004      F     FT    AWS   6.0   8.0   120.0
# 4   P005      M     PT     DS   7.0  11.0    58.0
# 5   P006      F     PT  other   1.0   7.5    75.0
# 6   P007      M     FT     FS   6.0   7.5     NaN
# 7   P008      F    NaN     FS  10.0   2.0   136.0
# 8   P009      M     PT  other  14.0   3.0    60.0
# 9   P010      F     FT     DS   6.0   7.0   125.0
# 10  P011      M    NaN    AWS   6.0   9.0     NaN

# %% [markdown]
# **where() Replace values where the condition is False.**

# %%
df.notna()
# Out:
#       id  gender  status   dept   var1   var2  salary
# 0   True    True    True   True   True   True   False
# 1   True    True    True   True   True  False    True
# 2   True    True   False   True   True   True    True
# 3   True    True    True   True  False   True    True
# 4   True    True    True   True   True   True    True
# 5   True    True    True  False   True  False    True
# 6   True    True    True   True  False  False   False
# 7   True    True   False   True   True   True    True
# 8   True    True    True  False   True   True    True
# 9   True    True    True   True  False   True    True
# 10  True    True   False   True   True   True   False

# %%
df.where(cond=df.notna(), other=df.mean(), axis = 1)
# Out:
# C:\Users\Ahmet\AppData\Local\Temp/ipykernel_2120/1324116707.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.where(cond=df.notna(), other=df.mean(), axis = 1)
#       id gender status dept  var1    var2   salary
# 0   P001      M     FT   DS   2.0   8.000   85.875
# 1   P002      F     PT   FS   3.0   6.625   54.000
# 2   P003      M    NaN  AWS   5.0   5.000   59.000
# 3   P004      F     FT  AWS   6.0   8.000  120.000
# 4   P005      M     PT   DS   7.0  11.000   58.000
# 5   P006      F     PT  NaN   1.0   6.625   75.000
# 6   P007      M     FT   FS   6.0   6.625   85.875
# 7   P008      F    NaN   FS  10.0   2.000  136.000
# 8   P009      M     PT  NaN  14.0   3.000   60.000
# 9   P010      F     FT   DS   6.0   7.000  125.000
# 10  P011      M    NaN  AWS   6.0   9.000   85.875

# %% [markdown]
# https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/

# %% [markdown]
#  #### c.Filling the Missing Values of Categorical Variables

# %%
df["dept"].mode() #hepsi aynı sayıda olduğu için hepsini verdi
# Out:
# 0    AWS
# 1     DS
# 2     FS
# dtype: object

# %%
df["dept"].mode()[0] #ilkini verir
# Out:
# 'AWS'

# %% [markdown]
#  #### d.Filling by condition & by Group of the Categorical Variables

# %%
df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"]>=100, "status"].mode()[0], inplace=True)
df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"]<100, "status"].mode()[0], inplace=True)
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F     FT   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.loc[df["salary"]>=100, "status"] = df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"]>=100, "status"].mode()[0])
df.loc[df["salary"]<100, "status"] = df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"]<100, "status"].mode()[0])
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F     FT   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.groupby(["gender", "dept"])["status"].apply(lambda x : x.mode()[0])
# Out:
# gender  dept
# F       AWS     FT
#         DS      FT
#         FS      FT
# M       AWS     PT
#         DS      FT
#         FS      FT
# Name: status, dtype: object

# %%
df["trans_status"] = df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Program Files\Python39\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2120/1358178234.py in <module>
# ----> 1 df["trans_status"] = df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0])
#       2 df
#
# C:\Program Files\Python39\lib\site-packages\pandas\core\groupby\generic.py in transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     503     @Appender(_transform_template)
#     504     def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# --> 505         return self._transform(
#     506             func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     507         )
#
# C:\Program Files\Python39\lib\site-packages\pandas\core\groupby\groupby.py in _transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    1444
#    1445         if not isinstance(func, str):
# -> 1446             return self._transform_general(func, *args, **kwargs)
#    1447
#    1448         elif func not in base.transform_kernel_allowlist:
#
# C:\Program Files\Python39\lib\site-packages\pandas\core\groupby\generic.py in _transform_general(self, func, *args, **kwargs)
#     534             # this setattr is needed for test_transform_lambda_with_datetimetz
#     535             object.__setattr__(group, "name", name)
# --> 536             res = func(group, *args, **kwargs)
#     537
#     538             results.append(klass(res, index=group.index))
#
# ~\AppData\Local\Temp/ipykernel_2120/1358178234.py in <lambda>(x)
# ----> 1 df["trans_status"] = df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0])
#       2 df
#
# C:\Program Files\Python39\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# C:\Program Files\Python39\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# C:\Program Files\Python39\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 0

# %%
df["status"].fillna(df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0]), inplace=True)
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F     FT   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M     PT  AWS   6.0   9.0     NaN

# %%
df.groupby("dept")["salary"].transform("mean")
# Out:
# 0     91.5
# 1     95.0
# 2     89.5
# 3     89.5
# 4     91.5
# 5      NaN
# 6     95.0
# 7     95.0
# 8      NaN
# 9     91.5
# 10    89.5
# Name: salary, dtype: float64

# %%
df.groupby(["status","dept"])["salary"].transform("mean")
# Out:
# 0     125.0
# 1      54.0
# 2      59.0
# 3     120.0
# 4      58.0
# 5       NaN
# 6     136.0
# 7     136.0
# 8       NaN
# 9     125.0
# 10     59.0
# Name: salary, dtype: float64

# %% [markdown]
# ### filling with Interpolation

# %% [markdown]
# Pandas dataframe.interpolate() function is basically used to fill NA values in the dataframe or series. But, this is a very powerful function to fill the missing values. It uses various interpolation technique to fill the missing values rather than hard-coding the value.
#
# https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html
